# %%
from gym_trading_env.renderer import Renderer
renderer = Renderer(render_logs_dir="logs")
renderer.run()
# Out:
#  * Serving Flask app 'gym_trading_env.renderer'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [17/Dec/2025 13:42:09] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2025 13:42:10] "GET /update_data/yfinance-STOXX50-1h.pkl_2025-12-16_21-21-54.pkl HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2025 13:42:10] "GET /metrics HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2025 13:42:10] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [17/Dec/2025 13:42:35] "GET /update_data/yfinance-AAPL-1h.pkl_2025-12-16_19-52-17.pkl HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2025 13:42:36] "GET /metrics HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2025 13:43:08] "GET /update_data/binance-BTCUSD-1h.pkl_2025-12-16_19-58-34.pkl HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2025 13:43:09] "GET /metrics HTTP/1.1" 200 -
# ...

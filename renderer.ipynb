# %%
from gym_trading_env.renderer import Renderer
renderer = Renderer(render_logs_dir="render_logs")
renderer.run()
# Out:
#  * Serving Flask app 'gym_trading_env.renderer'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [17/Dec/2025 15:10:03] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2025 15:10:05] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [17/Dec/2025 15:10:06] "GET /update_data/yfinance-EURUSD-1h.pkl_2025-12-17_15-09-39.pkl HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2025 15:10:06] "GET /metrics HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2025 16:28:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2025 16:28:02] "GET /update_data/yfinance-STOXX50-1h.pkl_2025-12-17_16-27-49.pkl HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2025 16:28:02] "GET /metrics HTTP/1.1" 200 -
# 127.0.0.1 - - [17/Dec/2025 16:28:19] "GET /update_data/yfinance-EURUSD-1h.pkl_2025-12-17_16-25-52.pkl HTTP/1.1" 200 -
# ...
